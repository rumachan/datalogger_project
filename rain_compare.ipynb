# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# Compare rainfall from both sensors
# --

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
loggerfile = 'Table1.csv'
dtstart = '2019-01-17T23:10:00'

# %% [markdown]
# **Read data**

# %%
df = pd.read_csv(loggerfile, parse_dates=True, index_col = 'Datetime')

#Use only data after logger was installed
data = df[df.index>=dtstart]

# %%
data.head()
# Out:
#                      RecNbr    LoggerName  SupplyVolts  LithiumVolts  \
# Datetime
# 2019-01-17 23:10:00       4  FoxLandslide        12.89         3.673
# 2019-01-17 23:20:00       5  FoxLandslide        12.90         3.671
# 2019-01-17 23:30:00       6  FoxLandslide        12.89         3.670
# 2019-01-17 23:40:00       7  FoxLandslide        12.90         3.672
# 2019-01-17 23:50:00       8  FoxLandslide        12.89         3.671
#
#                      PTemp_degC  Rain1_mm_Tot  Rain2_mm_Tot  \
# Datetime
# 2019-01-17 23:10:00   26.160000           0.0           0.0
# 2019-01-17 23:20:00   26.250000           0.0           0.0
# 2019-01-17 23:30:00   26.330000           0.0           0.0
# 2019-01-17 23:40:00   26.440001           0.0           0.0
# 2019-01-17 23:50:00   26.670000           0.0           0.0
#
#                      nmbr_satellites_Avg  latitude_a  latitude_b  longitude_a  \
# Datetime
# 2019-01-17 23:10:00                  4.5         -41    -11.7799          174
# 2019-01-17 23:20:00                  9.0         -41    -11.7799          174
# 2019-01-17 23:30:00                  9.0         -41    -11.7799          174
# 2019-01-17 23:40:00                  9.0         -41    -11.7799          174
# 2019-01-17 23:50:00                  9.0         -41    -11.7799          174
#
#                      longitude_b  speed  course  altitude
# Datetime
# 2019-01-17 23:10:00      55.9969      0   224.6      16.4
# 2019-01-17 23:20:00      55.9969      0   224.6      16.4
# 2019-01-17 23:30:00      55.9969      0   224.6      16.4
# 2019-01-17 23:40:00      55.9969      0   224.6      16.4
# 2019-01-17 23:50:00      55.9969      0   224.6      16.4

# %% [markdown]
# **Rainfall comparison**

# %%
nonzero = data[(data['Rain1_mm_Tot']>0) | (data['Rain2_mm_Tot']>0)]
nonzero
# Out:
#                      RecNbr    LoggerName  SupplyVolts  LithiumVolts  \
# Datetime
# 2019-01-19 12:50:00     230  FoxLandslide        12.81         3.674
# 2019-01-19 13:10:00     232  FoxLandslide        12.82         3.678
# 2019-01-19 13:20:00     233  FoxLandslide        12.82         3.678
# 2019-01-19 13:40:00     235  FoxLandslide        12.81         3.676
# 2019-01-23 09:50:00     788  FoxLandslide        12.62         3.674
# 2019-01-23 10:00:00     789  FoxLandslide        12.62         3.676
# 2019-01-23 10:20:00     791  FoxLandslide        12.62         3.676
# 2019-01-23 10:30:00     792  FoxLandslide        12.64         3.674
# 2019-01-23 10:40:00     793  FoxLandslide        12.62         3.676
# 2019-01-23 10:50:00     794  FoxLandslide        12.62         3.676
# 2019-01-23 11:00:00     795  FoxLandslide        12.62         3.677
# 2019-01-24 22:20:00    1007  FoxLandslide        12.58         3.675
# 2019-01-24 22:30:00    1008  FoxLandslide        12.54         3.674
#
#                      PTemp_degC  Rain1_mm_Tot  Rain2_mm_Tot  \
# Datetime
# 2019-01-19 12:50:00   20.719999           0.4           0.0
# 2019-01-19 13:10:00   20.549999           0.2           0.0
# 2019-01-19 13:20:00   20.469999           0.2           0.0
# 2019-01-19 13:40:00   20.340000           0.2           0.0
# 2019-01-23 09:50:00   21.000000           0.2           0.0
# 2019-01-23 10:00:00   20.889999           0.2           0.0
# 2019-01-23 10:20:00   20.719999           0.4           0.0
# 2019-01-23 10:30:00   20.639999           0.2           1.0
# 2019-01-23 10:40:00   20.570000           1.6           1.0
# 2019-01-23 10:50:00   20.400000           7.6           7.0
# 2019-01-23 11:00:00   20.059999           1.8           1.0
# 2019-01-24 22:20:00   28.320000           0.0           1.0
# 2019-01-24 22:30:00   28.080000           0.0           1.0
#
#                      nmbr_satellites_Avg  latitude_a  latitude_b  longitude_a  \
# Datetime
# 2019-01-19 12:50:00                 11.0         -41    -11.7798          174
# 2019-01-19 13:10:00                 10.5         -41    -11.7829          174
# 2019-01-19 13:20:00                 10.0         -41    -11.7829          174
# 2019-01-19 13:40:00                 10.0         -41    -11.7829          174
# 2019-01-23 09:50:00                 10.0         -41    -11.7815          174
# 2019-01-23 10:00:00                 10.0         -41    -11.7815          174
# 2019-01-23 10:20:00                 10.0         -41    -11.7795          174
# 2019-01-23 10:30:00                 10.0         -41    -11.7795          174
# 2019-01-23 10:40:00                 10.0         -41    -11.7795          174
# 2019-01-23 10:50:00                 10.0         -41    -11.7795          174
# 2019-01-23 11:00:00                 10.0         -41    -11.7795          174
# 2019-01-24 22:20:00                  0.0           0      0.0000            0
# 2019-01-24 22:30:00                  0.0           0      0.0000            0
#
#                      longitude_b  speed  course  altitude
# Datetime
# 2019-01-19 12:50:00      55.9964      0   353.9      29.1
# 2019-01-19 13:10:00      55.9954      0   267.9      21.3
# 2019-01-19 13:20:00      55.9954      0   267.9      21.3
# 2019-01-19 13:40:00      55.9954      0   267.9      21.3
# 2019-01-23 09:50:00      55.9983      0     0.0      15.1
# 2019-01-23 10:00:00      55.9983      0     0.0      15.1
# 2019-01-23 10:20:00      55.9965      0     0.0      17.3
# 2019-01-23 10:30:00      55.9965      0     0.0      17.3
# 2019-01-23 10:40:00      55.9965      0     0.0      17.3
# 2019-01-23 10:50:00      55.9965      0     0.0      17.3
# 2019-01-23 11:00:00      55.9965      0     0.0      17.3
# 2019-01-24 22:20:00       0.0000      0     0.0       0.0
# 2019-01-24 22:30:00       0.0000      0     0.0       0.0

# %%
maxrain = np.maximum(nonzero['Rain1_mm_Tot'].max(), nonzero['Rain1_mm_Tot'].max())
maxrain
# Out:
# 7.6

# %%
fig,ax = plt.subplots(1, 1, figsize=(5,5))
nonzero.plot.scatter(ax=ax, x='Rain1_mm_Tot', y='Rain2_mm_Tot')

ax.plot([0,maxrain],[0,maxrain])

ax.set_ylim(0,maxrain)
ax.set_xlim(0,maxrain)
ax.set_title('Non-zero rainfall observations')

fig.savefig('rain_compare.png')
